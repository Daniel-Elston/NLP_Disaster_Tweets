# %%
import sys
import os

import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split

# %%
root_dir = 'C:/Users/delst/OneDrive/Desktop/Code/Workspace/NLP_Disaster_Tweets'
sys.path.append(root_dir)

from A_Main.Configurations.setup_env import setup_environment
config = setup_environment(root_dir)

# %% [markdown]
# ---

# %%
raw_data_path_train = config.raw_data_train
raw_data_path_test = config.raw_data_test

# %%
# Read csv files
df_train = pd.read_csv(raw_data_path_train)
df_test = pd.read_csv(raw_data_path_test)

display(df_train.head())
display(df_test.head())
# Out:
#    id keyword location                                               text  \
# 0   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 1   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 2   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 3   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
# 4   8     NaN      NaN  #RockyFire Update => California Hwy. 20 closed...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#    id keyword location                                               text
# 0   0     NaN      NaN                 Just happened a terrible car crash
# 1   2     NaN      NaN  Heard about #earthquake is different cities, s...
# 2   3     NaN      NaN  there is a forest fire at spot pond, geese are...
# 3   9     NaN      NaN           Apocalypse lighting. #Spokane #wildfires
# 4  11     NaN      NaN      Typhoon Soudelor kills 28 in China and Taiwan

# %% [markdown]
# ---

# %% [markdown]
# # **Create Validation Set**

# %% [markdown]
# For the purpose of this project, the training dataset is split into training and validation sets, in order to later perform model evaluation.

# %%
df_val = df_train.sample(frac=0.2, random_state=42)
df_val
# Out:
#          id         keyword                  location  \
# 6049  10813         wrecked                       NaN
# 1612   2944          danger                  2005 |-/
# 1718   3124          debris  Hamilton, Ontario Canada
# 561    1038        bleeding           Vero Beach , FL
# 5359   9612    thunderstorm                       NaN
# ...     ...             ...                       ...
# 2154   3932      devastated                       NaN
# 5891  10546       windstorm       Georgia ? Tennessee
# 30       56          ablaze                       NaN
# 789    1441  body%20bagging                  New Your
# 5453   9788         trapped      å_å_Los Mina Cityã¢
#
#                                                    text  target
# 6049  @__ohhmyjoshh @stevenrulles he not gonna be th...       0
# 1612  i wanna get a danger days tattoo so bad how co...       0
# 1718  Malaysia seem more certain than France.\r\n\r\...       1
# 561   @JaydenNotJared I can't help it. Hope you're o...       0
# 5359  Severe Thunderstorm Warning issued August 05 a...       1
# ...                                                 ...     ...
# 2154  Bairstow dropped his buffet ticket there. Deva...       0
# 5891  When I breathe it sounds like a windstorm. Hah...       0
# 30    Barbados #Bridgetown JAMAICA ÛÒ Two cars set ...       1
# 789   @BroseidonRex @dapurplesharpie I skimmed throu...       0
# 5453  Hollywood Movie About Trapped Miners Released ...       0
#
# [1218 rows x 5 columns]

# %%
sampled_indices = df_val.index

df_train = df_train.drop(sampled_indices)
df_train
# Out:
#          id keyword location  \
# 0         4     NaN      NaN
# 1         5     NaN      NaN
# 2         6     NaN      NaN
# 3         7     NaN      NaN
# 4         8     NaN      NaN
# ...     ...     ...      ...
# 6085  10866     NaN      NaN
# 6086  10867     NaN      NaN
# 6087  10870     NaN      NaN
# 6088  10871     NaN      NaN
# 6089  10872     NaN      NaN
#
#                                                    text  target
# 0                Forest fire near La Ronge Sask. Canada       1
# 1     All residents asked to 'shelter in place' are ...       1
# 2     13,000 people receive #wildfires evacuation or...       1
# 3     Just got sent this photo from Ruby #Alaska as ...       1
# 4     #RockyFire Update => California Hwy. 20 closed...       1
# ...                                                 ...     ...
# 6085  Suicide bomber kills 15 in Saudi security site...       1
# 6086  #stormchase Violent Record Breaking EF-5 El Re...       1
# 6087  @aria_ahrary @TheTawniest The out of control w...       1
# 6088  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1
# 6089  Police investigating after an e-bike collided ...       1
#
# [4872 rows x 5 columns]

# %% [markdown]
# ---

# %%
# # save df to csv
# df_train.to_csv('C:/Users/delst/OneDrive/Desktop/Code/Workspace/NLP_Disaster_Tweets/Data/A_Raw/train_split.csv', index=False)
# df_val.to_csv('C:/Users/delst/OneDrive/Desktop/Code/Workspace/NLP_Disaster_Tweets/Data/A_Raw/validation.csv', index=False)

# %% [markdown]
# ---

# %%
display(df_train.head())
display(df_val.head())
display(df_test.head())
# Out:
#    id keyword location                                               text  \
# 0   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 1   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 2   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 3   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
# 4   8     NaN      NaN  #RockyFire Update => California Hwy. 20 closed...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#          id       keyword                  location  \
# 6049  10813       wrecked                       NaN
# 1612   2944        danger                  2005 |-/
# 1718   3124        debris  Hamilton, Ontario Canada
# 561    1038      bleeding           Vero Beach , FL
# 5359   9612  thunderstorm                       NaN
#
#                                                    text  target
# 6049  @__ohhmyjoshh @stevenrulles he not gonna be th...       0
# 1612  i wanna get a danger days tattoo so bad how co...       0
# 1718  Malaysia seem more certain than France.\r\n\r\...       1
# 561   @JaydenNotJared I can't help it. Hope you're o...       0
# 5359  Severe Thunderstorm Warning issued August 05 a...       1
#    id keyword location                                               text
# 0   0     NaN      NaN                 Just happened a terrible car crash
# 1   2     NaN      NaN  Heard about #earthquake is different cities, s...
# 2   3     NaN      NaN  there is a forest fire at spot pond, geese are...
# 3   9     NaN      NaN           Apocalypse lighting. #Spokane #wildfires
# 4  11     NaN      NaN      Typhoon Soudelor kills 28 in China and Taiwan

# %%
print(df_train.shape)
print(df_val.shape)
print(df_test.shape)
# Out:
# (4872, 5)
# (1218, 5)
# (3263, 4)
