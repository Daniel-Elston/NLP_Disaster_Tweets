# %%
import sys
import os

import pandas as pd

# %%
project_dir = 'C:/Users/delst/OneDrive/Desktop/Code/Workspace/NLP_Disaster_Tweets'
config_subdir = 'A_Root_Dir/Configurations'
config_filename = 'virt_env.yaml'

config_dir = os.path.join(project_dir, config_subdir)
sys.path.append(config_dir)

config_path = os.path.join(config_dir, config_filename)

from config_loader import ConfigLoader

config = ConfigLoader(config_path, globals())
config.load()

# %% [markdown]
# ---

# %%
# Now use the loaded paths
train_data_dir = config.raw_data_train
test_data_dir = config.raw_data_test

df_train = pd.read_csv(train_data_dir)
df_test = pd.read_csv(test_data_dir)

display(df_train.head())
display(df_test.head())
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#    id keyword location                                               text
# 0   0     NaN      NaN                 Just happened a terrible car crash
# 1   2     NaN      NaN  Heard about #earthquake is different cities, s...
# 2   3     NaN      NaN  there is a forest fire at spot pond, geese are...
# 3   9     NaN      NaN           Apocalypse lighting. #Spokane #wildfires
# 4  11     NaN      NaN      Typhoon Soudelor kills 28 in China and Taiwan

# %% [markdown]
# ---

# %%
# # LOAD
# file_name = 'c1_init_process_train.parquet'
# load_dir = 'C:/Users/delst/OneDrive/Desktop/Code/Workspace/NLP_Disaster_Tweets/Data/Z_Output_Data'
# df = load_from_parquet(file_name, load_dir)

# %% [markdown]
# ---

# %%
# config.parquet_train

# %%
# Now use the loaded paths
# file_name = 'c1_init_process_test.parquet'

train_data_dir = config.parquet_train
pd.read_parquet(train_data_dir)
# test_data_dir = config.raw_data_test

# df_train = load_from_parquet(file_name, train_data_dir)
# # df_test = pd.read_csv(test_data_dir)

# display(df_train.head())
# # display(df_test.head())
# Out:
#          id  keyword                                               text  \
# 31       48   ablaze  @bbcmtd wholesale markets ablaze http://t.co/l...
# 32       49   ablaze  we always try to bring the heavy. #metal #rt h...
# 33       50   ablaze  #africanbaze: breaking news:nigeria flag set a...
# 34       52   ablaze                 crying out for more! set me ablaze
# 35       53   ablaze  on plus side look at the sky last night it was...
# ...     ...      ...                                                ...
# 7578  10830  wrecked   @jt_ruff23 @cameronhacker and i wrecked you both
# 7579  10831  wrecked  three days off from work and they've pretty mu...
# 7580  10832  wrecked  #fx #forex #trading cramer: iger's 3 words tha...
# 7581  10833  wrecked  @engineshed great atmosphere at the british li...
# 7582  10834  wrecked  cramer: iger's 3 words that wrecked disney's s...
#
#       target
# 31         1
# 32         0
# 33         1
# 34         0
# 35         0
# ...      ...
# ...

# %%
pd.read_parquet(train_data_dir)
# Out:
#          id  keyword                                               text  \
# 31       48   ablaze  @bbcmtd wholesale markets ablaze http://t.co/l...
# 32       49   ablaze  we always try to bring the heavy. #metal #rt h...
# 33       50   ablaze  #africanbaze: breaking news:nigeria flag set a...
# 34       52   ablaze                 crying out for more! set me ablaze
# 35       53   ablaze  on plus side look at the sky last night it was...
# ...     ...      ...                                                ...
# 7578  10830  wrecked   @jt_ruff23 @cameronhacker and i wrecked you both
# 7579  10831  wrecked  three days off from work and they've pretty mu...
# 7580  10832  wrecked  #fx #forex #trading cramer: iger's 3 words tha...
# 7581  10833  wrecked  @engineshed great atmosphere at the british li...
# 7582  10834  wrecked  cramer: iger's 3 words that wrecked disney's s...
#
#       target
# 31         1
# 32         0
# 33         1
# 34         0
# 35         0
# ...      ...
# ...
